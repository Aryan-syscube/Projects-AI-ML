# %% [markdown]
# ## Netflix Content Analysis 🎬
#
# **Project Objective:** To perform an in-depth exploratory data analysis of the Netflix dataset. We will explore trends in content production, identify popular genres, analyze content ratings, and understand the distribution of movies and TV shows on the platform. This project builds on foundational EDA by introducing time-series analysis and more complex data cleaning and transformation techniques.

# %%
# Use plain tracebacks to avoid "Unexpected exception formatting exception" on Python 3.13
# %xmode Plain

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# Set a consistent style for our plots
sns.set_style('darkgrid')
# Out:
# Exception reporting mode: Plain

# %%
# Directors can be multiple per title (comma-separated); split and count each
director_series = netflix_df['director'].dropna()
all_directors = []
for d in director_series:
    for name in str(d).split(','):
        name = name.strip()
        if name:
            all_directors.append(name)

director_counts = pd.Series(all_directors).value_counts()
top_directors = director_counts.head(15)

print("Top 15 directors on Netflix (by number of titles):")
print(top_directors.to_string())

plt.figure(figsize=(10, 6))
top_directors.plot(kind='barh', color='darkorange', alpha=0.8)
plt.xlabel('Number of titles')
plt.title('Top 15 Directors on Netflix')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
